# %% [markdown]
# <a href="https://colab.research.google.com/github/Slipgrass/Loginova/blob/main/Loginova_math_HT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x = np.linspace(0, 20, 100)
k1 = 1
k2 = 3
plt.plot(x, np.cos(k1*x), color='purple', linewidth=2)
plt.plot(x, np.cos(k2*x), color='red', linestyle='dashed', linewidth=2)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
